# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('data.csv', header=None)
df
# Out:
#           0         1
# 0    6.1101  17.59200
# 1    5.5277   9.13020
# 2    8.5186  13.66200
# 3    7.0032  11.85400
# 4    5.8598   6.82330
# ..      ...       ...
# 92   5.8707   7.20290
# 93   5.3054   1.98690
# 94   8.2934   0.14454
# 95  13.3940   9.05510
# 96   5.4369   0.61705
#
# [97 rows x 2 columns]

# %%
plt.scatter(df[0],df[1])

# %% [markdown]
# #  The data is 2 dimensional. Increasing the dimension of our data using Polynomial Features

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=3)

# %%
X=df[0].values
y=df[1].values

# %%
X=X.reshape((X.shape[0],1))
X=poly.fit_transform(X)

# %%
X=X/X.max()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2, random_state=100)

# %%
from Linear_Regression import LinearRegressionMGD

# %%
model=LinearRegressionMGD()

# %%
# %time model.fit(X_train,y_train, lr=1e-2, batch_size=10, epochs=3000, threshold=1e-8)
# Out:
#  Epoch: 1 Cost: 3559.5175114612634
#  Epoch: 2 Cost: 3121.3844223137507
#  Epoch: 3 Cost: 2794.1156381372266
#  Epoch: 4 Cost: 2547.2511264979394
#  Epoch: 5 Cost: 2358.895585752779
#  Epoch: 6 Cost: 2214.2025351607144
#  Epoch: 7 Cost: 2118.992175573704
#  Epoch: 8 Cost: 2034.1434103754614
#  Epoch: 9 Cost: 1967.0436967709106
#  Epoch: 10 Cost: 1916.4855138068917
#  Epoch: 11 Cost: 1873.4965793706947
#  Epoch: 12 Cost: 1842.9089215716926
#  Epoch: 13 Cost: 1824.5286300519506
#  Epoch: 14 Cost: 1807.682518221794
#  Epoch: 15 Cost: 1785.820573111121
#  Epoch: 16 Cost: 1768.3433870556607
#  Epoch: 17 Cost: 1756.4378282663104
#  Epoch: 18 Cost: 1745.6395328501708
#  Epoch: 19 Cost: 1735.3478488681965
#  Epoch: 20 Cost: 1726.071128660721
#  Epoch: 21 Cost: 1717.3340498891796
#  Epoch: 22 Cost: 1712.9180383768958
#  Epoch: 23 Cost: 1704.7039214531512
#  Epoch: 24 Cost: 1698.08911247127
#  Epoch: 25 Cost: 1690.6175281751628
#  Epoch: 26 Cost: 1683.3059647891475
# ...

# %% [markdown]
# # Loss Decreasing Graph

# %%
plt.plot(range(len(model.costs)), model.costs)
plt.title('Loss at epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# # r2 score calculation

# %%
from sklearn.metrics import r2_score
y_pred=model.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.5860958298513201
